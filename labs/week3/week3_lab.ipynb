-- %% [markdown]
-- # Week 3 Lab: Testing SQL INSERT Statements
--
-- In this notebook, you'll write SQL INSERT statements and then write tests to verify the results.
-- Each INSERT loads filtered rows from `week3_testing.employees` into `week3_testing.filtered_employees`.
--
-- Each cell is tagged with `-- @test:tag_name` so tests can find and run it.
--
-- **Domain:** Employee/HR data (different from the bookstore domain in weeks 4-6)
--
-- ## Setup
--
-- Before starting, run `create_week3_tables.ipynb` to set up the test schema.

-- %% [markdown]
-- ## Setup: Set Your Catalog
--
-- **IMPORTANT:** Before running any queries, set your assigned catalog name.

-- %%
-- TODO: Replace with your assigned catalog name
USE CATALOG student_demo;

-- %% [markdown]
-- ## Exercise 1: Insert Employees with Valid Email
--
-- Insert employees with a valid email address into `filtered_employees`.
-- Valid format: email is not NULL and contains an `@` symbol (e.g., `name@company.com`)

-- %%
-- @test:valid_email_filter
-- TODO: Write an INSERT INTO week3_testing.filtered_employees selecting employees with a valid email

-- %% [markdown]
-- ## Exercise 2: Insert Employees in Salary Range
--
-- Insert employees with salaries from $50,000 to $100,000 (inclusive) into `filtered_employees`.

-- %%
-- @test:employees_in_salary_range
-- TODO: Write an INSERT INTO week3_testing.filtered_employees selecting employees in the salary range

-- %% [markdown]
-- ## Exercise 3: Insert Recent Hires
--
-- Insert employees hired after January 1, 2026 into `filtered_employees`.

-- %%
-- @test:recent_hires
-- TODO: Write an INSERT INTO week3_testing.filtered_employees selecting employees hired after 2026-01-01

-- %% [markdown]
-- ## Exercise 4: Insert Engineering Employees
--
-- Insert only employees from the Engineering department into `filtered_employees`.

-- %%
-- @test:engineering_department_filter
-- TODO: Write an INSERT INTO week3_testing.filtered_employees selecting only Engineering employees

-- %% [markdown]
-- ## Next Steps
--
-- Now that you've written these INSERT statements:
--
-- 1. Go to `tests/test_week3_sql.py`
-- 2. Write tests that run each tagged INSERT
-- 3. After each INSERT, query `filtered_employees` to verify the results
-- 4. Run `pytest tests/test_week3_sql.py -v`
--
-- Remember: each test should:
-- - Use `_run_cell()` to run the INSERT from this notebook
-- - Query `week3_testing.filtered_employees` with `spark.sql()` to get the results
-- - Use `assert` to verify the correct rows were inserted
